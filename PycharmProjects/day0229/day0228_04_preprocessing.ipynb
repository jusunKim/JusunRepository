# %%
#exam.csv 파일 내용을 읽어들여 출력
from google.colab import drive
import pandas as pd

# %%
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
exam = pd.read_csv("gdrive/My Drive/exam.csv")
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam['nclass'].value_counts()
# Out:
# 1    4
# 2    4
# 3    4
# 4    4
# 5    4
# Name: nclass, dtype: int64

# %%
#1반 학생만 조회
exam[exam['nclass']==1]
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
#1반 제외 학생 조회
exam[exam['nclass']!=1]
# Out:
#     id  nclass  math  english  science
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
#수학이 50점이상인 학생 조회
exam[exam['math']>=50]
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
#1반 중에서 수학이 50점 이상
exam[(exam['nclass']==1)&(exam['math']>=50)]
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
#1반이거나 수학 50점 이상
exam[(exam['nclass']==1)|(exam['math']>=50)]
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
#1반이나3반이나 5반인애들
exam[(exam['nclass']==1)|(exam['nclass']==3)|(exam['nclass']==5)]
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
# 쿼리함수를 이용해 조회하기
# 데이터프레임.query(조건식)+
exam.query('nclass==1')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
#1반제외학생
# exam.query('nclass!=1')
# 1반이거나 수학 50점 이상
# exam.query('(nclass==1)|(math>=50)')
#1반이면서 수학 50점이상
# exam.query('(nclass==1)&(math>=50)')
#1/3/5반
# exam.query('(nclass==1)|(nclass==3)|(nclass==5)')
exam.query('nclass in [1,3,5]')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
p1 = exam.pivot_table(values='math',index='nclass')
print(p1)
print(p1.loc[1])
print(p1.loc[2])
# Out:
#          math
# nclass
# 1       46.25
# 2       61.25
# 3       45.00
# 4       56.75
# 5       78.00
# math    46.25
# Name: 1, dtype: float64
# math    61.25
# Name: 2, dtype: float64

# %%
nclass1 = exam.query('nclass==1')
nclass2 = exam.query('nclass==2')

# %%
nclass1['math'].mean()
# Out:
# 46.25

# %%
nclass2['math'].mean()
# Out:
# 61.25

# %%
nclass1
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam.query('nclass in [1,2]').groupby('nclass')['math'].mean()
# Out:
# nclass
# 1    46.25
# 2    61.25
# Name: math, dtype: float64

# %%
p1 = exam.query('nclass in [1,2]').pivot_table(values='math',index='nclass')
p1
# Out:
#          math
# nclass
# 1       46.25
# 2       61.25

# %%
df = pd.DataFrame({
    'id':[100,101,102,103],
    'sex':['F','M','F','M'],
    'country':['korea','china','japan','usa']
})

# %%
#여자만조회
df.query('sex=="F"')
# Out:
#     id sex country
# 0  100   F   korea
# 2  102   F   japan

# %%
#여자 중 한국인 조회
df.query('sex=="F"&country=="korea"')
# Out:
#     id sex country
# 0  100   F   korea

# %%
n=3
exam.query('nclass==@n')
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32

# %%
exam['math']
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam[['nclass','math','english']]
# Out:
#     nclass  math  english
# 0        1    50       98
# 1        1    60       97
# 2        1    45       86
# 3        1    30       98
# 4        2    25       80
# 5        2    50       89
# 6        2    80       90
# 7        2    90       78
# 8        3    20       98
# 9        3    50       98
# 10       3    65       65
# 11       3    45       85
# 12       4    46       98
# 13       4    48       87
# 14       4    75       56
# 15       4    58       98
# 16       5    65       68
# 17       5    80       78
# 18       5    89       68
# 19       5    78       83

# %%
exam[['math']]
# Out:
#     math
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78

# %%
# 수집한 원본 데이터로부터 분석에 필요한 데이터 추출 위해 필요한 변수만 추출할 수도 있고 필요없는 변수 삭제할 수도 잇삼

# 필요한 변수(컬럼)만 추출하기
# df = df[ [ '변수1', '변수2'] ]

# 필요없는 변수(컬럼)삭제하기
# df.drop(columns=['변수1', '변수2',...])

# %%
#exam으로부터 분석에 필요한 id, math, english만 추출하기
ex1 = exam[['id','math','english']]
ex1
# Out:
#     id  math  english
# 0    1    50       98
# 1    2    60       97
# 2    3    45       86
# 3    4    30       98
# 4    5    25       80
# 5    6    50       89
# 6    7    80       90
# 7    8    90       78
# 8    9    20       98
# 9   10    50       98
# 10  11    65       65
# 11  12    45       85
# 12  13    46       98
# 13  14    48       87
# 14  15    75       56
# 15  16    58       98
# 16  17    65       68
# 17  18    80       78
# 18  19    89       68
# 19  20    78       83

# %%
df2 = exam.copy()
# df2 = df2.drop(columns=['nclass','science'])
df2.drop(columns=['nclass','science'], inplace=True) #inplace=True 쓰면 자기자신한테 assign안해도댐
df2
# Out:
#     id  math  english
# 0    1    50       98
# 1    2    60       97
# 2    3    45       86
# 3    4    30       98
# 4    5    25       80
# 5    6    50       89
# 6    7    80       90
# 7    8    90       78
# 8    9    20       98
# 9   10    50       98
# 10  11    65       65
# 11  12    45       85
# 12  13    46       98
# 13  14    48       87
# 14  15    75       56
# 15  16    58       98
# 16  17    65       68
# 17  18    80       78
# 18  19    89       68
# 19  20    78       83

# %%
#1반학생의 영어점수만 뽑아 데잍어프레임만들기
df = exam.query('nclass==1')[['english']]
df
# Out:
#    english
# 0       98
# 1       97
# 2       86
# 3       98

# %%
#수학이 50점이상인학생들의 아이디랑 수학점수만 추출
exam.query('math>=50')[['id','math']]
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65
# 17  18    80
# 18  19    89
# 19  20    78

# %%
#수학점수가 50점이상인학생들의아이디와 수학점수만 추출해 앞5개만 데이터프레임
exam.query('math>=50')[['id','math']].head()
# Out:
#    id  math
# 0   1    50
# 1   2    60
# 5   6    50
# 6   7    80
# 7   8    90

# %%
#수학점수순정렬
exam.sort_values(['math'])
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 4    5       2    25       80       65
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 0    1       1    50       98       50
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 15  16       4    58       98       65
# 1    2       1    60       97       60
# 10  11       3    65       65       65
# 16  17       5    65       68       98
# 14  15       4    75       56       78
# 19  20       5    78       83       58
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 7    8       2    90       78       25

# %%
#수학점수높은순정렬
exam.sort_values(by='math',ascending=False)
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 6    7       2    80       90       45
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 10  11       3    65       65       65
# 1    2       1    60       97       60
# 15  16       4    58       98       65
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 0    1       1    50       98       50
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 11  12       3    45       85       32
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15

# %%
# 만약 정렬해야 하는 컬럼이 두 개 이상이면? 배열을 준다
# df.sort_values(by = ['컬럼1','컬럼2']) ==> 컬럼1 asc, 컬럼2 asc
# df.sort_values(by = ['컬럼1','컬럼2'], ascending=[True, False]) => 컬럼1은 오름차순, 컬럼2 내림차순

# %%
#연습) 반별로 출력하되 동일할 때에ㅅ는 수학점수 높은순 출력
df1 = exam.sort_values(by=['nclass','math'], ascending=[True, False])
df1
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 7    8       2    90       78       25
# 6    7       2    80       90       45
# 5    6       2    50       89       98
# 4    5       2    25       80       65
# 10  11       3    65       65       65
# 9   10       3    50       98       45
# 11  12       3    45       85       32
# 8    9       3    20       98       15
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 16  17       5    65       68       98

# %%
student = exam.copy()
#student에 수학, 과학, 영어 합한 total파생변수 추가

# %%
student['total'] = student['math']+student['english']+student['science']
student
# Out:
#     id  nclass  math  english  science  total
# 0    1       1    50       98       50    198
# 1    2       1    60       97       60    217
# 2    3       1    45       86       78    209
# 3    4       1    30       98       58    186
# 4    5       2    25       80       65    170
# 5    6       2    50       89       98    237
# 6    7       2    80       90       45    215
# 7    8       2    90       78       25    193
# 8    9       3    20       98       15    133
# 9   10       3    50       98       45    193
# 10  11       3    65       65       65    195
# 11  12       3    45       85       32    162
# 12  13       4    46       98       65    209
# 13  14       4    48       87       12    147
# 14  15       4    75       56       78    209
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 17  18       5    80       78       90    248
# 18  19       5    89       68       87    244
# ...

# %%
# 파생변수 추가를 위한 판다스의 assign() 이용하기
# df.assign(변수명=값)

# %%
student = exam.copy()
student = student.assign(total=student['math']+student['english']+student['science'])
student
# Out:
#     id  nclass  math  english  science  total
# 0    1       1    50       98       50    198
# 1    2       1    60       97       60    217
# 2    3       1    45       86       78    209
# 3    4       1    30       98       58    186
# 4    5       2    25       80       65    170
# 5    6       2    50       89       98    237
# 6    7       2    80       90       45    215
# 7    8       2    90       78       25    193
# 8    9       3    20       98       15    133
# 9   10       3    50       98       45    193
# 10  11       3    65       65       65    195
# 11  12       3    45       85       32    162
# 12  13       4    46       98       65    209
# 13  14       4    48       87       12    147
# 14  15       4    75       56       78    209
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 17  18       5    80       78       90    248
# 18  19       5    89       68       87    244
# ...

# %%
# 한번에 여러개의 파생변수 만들기
# assign(변수1 = 값1, 변수2=값2...)
student = exam.copy()
student = student.assign(total=student['math']+student['english']+student['science'],mean =(student['math']+student['english']+student['science'])/3 )
student
# Out:
#     id  nclass  math  english  science  total       mean
# 0    1       1    50       98       50    198  66.000000
# 1    2       1    60       97       60    217  72.333333
# 2    3       1    45       86       78    209  69.666667
# 3    4       1    30       98       58    186  62.000000
# 4    5       2    25       80       65    170  56.666667
# 5    6       2    50       89       98    237  79.000000
# 6    7       2    80       90       45    215  71.666667
# 7    8       2    90       78       25    193  64.333333
# 8    9       3    20       98       15    133  44.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 11  12       3    45       85       32    162  54.000000
# 12  13       4    46       98       65    209  69.666667
# 13  14       4    48       87       12    147  49.000000
# 14  15       4    75       56       78    209  69.666667
# ...

# %%
student = exam.copy()
student = student.assign(total=lambda x: x['math']+x['english']+x['science'],mean =lambda y: y['total']/3 )
student
# Out:
#     id  nclass  math  english  science  total       mean
# 0    1       1    50       98       50    198  66.000000
# 1    2       1    60       97       60    217  72.333333
# 2    3       1    45       86       78    209  69.666667
# 3    4       1    30       98       58    186  62.000000
# 4    5       2    25       80       65    170  56.666667
# 5    6       2    50       89       98    237  79.000000
# 6    7       2    80       90       45    215  71.666667
# 7    8       2    90       78       25    193  64.333333
# 8    9       3    20       98       15    133  44.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 11  12       3    45       85       32    162  54.000000
# 12  13       4    46       98       65    209  69.666667
# 13  14       4    48       87       12    147  49.000000
# 14  15       4    75       56       78    209  69.666667
# ...

# %%
exam.stack()
# Out:
# 0   id          1
#     nclass      1
#     math       50
#     english    98
#     science    50
#                ..
# 19  id         20
#     nclass      5
#     math       78
#     english    83
#     science    58
# Length: 100, dtype: int64

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
# 수학 점수의 평균
student['math'].mean()
# Out:
# 57.45

# %%
#1반학생들의 수학점수의 평균
student.query('nclass==1')['math'].mean()
# Out:
# 46.25

# %%
#각 반별 수학점수의 평균
# nclass로 그룹화하면 디폴트로 걔가 index가 된다
a = student.groupby('nclass').agg(meanMath = ('math','mean'))
a
# Out:
#         meanMath
# nclass
# 1          46.25
# 2          61.25
# 3          45.00
# 4          56.75
# 5          78.00

# %%
# 그룹화한 nclass를 인덱스로 쓰고 싶지 않다면
student.groupby('nclass', as_index=False).agg(meanMath = ('math','mean'))
# Out:
#    nclass  meanMath
# 0       1     46.25
# 1       2     61.25
# 2       3     45.00
# 3       4     56.75
# 4       5     78.00

# %%
# 한번에 여러 함수를 메소드 체이닝 하면 줄 길어져서 가독성 떨어져. -> 한줄에 하나만 쓰고 줄 바꿔서 다른함수 쓸 수 있느데
# 구분 기호로 역슬래시를 쓴다
student.groupby('nclass',as_index=False)\
.agg(mean_math = ('math','mean'), mean_eng= ('science','mean'))
# Out:
#    nclass  mean_math  mean_eng
# 0       1      46.25     61.50
# 1       2      61.25     58.25
# 2       3      45.00     39.25
# 3       4      56.75     55.00
# 4       5      78.00     83.25

# %%
#한꺼번에 여러 개의 요약통계량 구하기
student.groupby('nclass',as_index=False)\
.agg(mean_math = ('math','mean'), median_math= ('math','median'),
     sum_math= ('math','sum'), count_math= ('math','count'))
# Out:
#    nclass  mean_math  median_math  sum_math  count_math
# 0       1      46.25         47.5       185           4
# 1       2      61.25         65.0       245           4
# 2       3      45.00         47.5       180           4
# 3       4      56.75         53.0       227           4
# 4       5      78.00         79.0       312           4

# %%
student.groupby('nclass',as_index=False).agg(mean_math = ('math','mean'))
# Out:
#    nclass  mean_math
# 0       1      46.25
# 1       2      61.25
# 2       3      45.00
# 3       4      56.75
# 4       5      78.00

# %%
#모든 변수에 대해 한번에 요약통계량 구하기
student.groupby('nclass', as_index=False).mean()
# Out:
#    nclass    id   math  english  science   total       mean
# 0       1   2.5  46.25    94.75    61.50  202.50  67.500000
# 1       2   6.5  61.25    84.25    58.25  203.75  67.916667
# 2       3  10.5  45.00    86.50    39.25  170.75  56.916667
# 3       4  14.5  56.75    84.75    55.00  196.50  65.500000
# 4       5  18.5  78.00    74.25    83.25  235.50  78.500000
